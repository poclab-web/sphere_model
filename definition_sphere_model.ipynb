# %%
import py3Dmol
import copy
from sphere_model_lib import render_moleculer
import json
import numpy as np
from itertools import product
import pandas as pd

# %%
param=[1.5,2,100]
param=[2,3,80]
param=[1,1,90]
center=[param[1]*np.cos(np.radians(param[2])),0,param[1]*np.sin(np.radians(param[2]))]
radius=param[0]
dir_name="/Volumes/SSD-PSM960U3-UW/b3lyp_6-31g(d)_b3lyp_6-31g(d)_single_point_calculation/KPMKEVXVVHNIEY-NTSWFWBYSA-N"#"/YKFKEYKJGVSEIX-BAUXJJEQSA-N"#"/KPMKEVXVVHNIEY-NTSWFWBYSA-N"


mol = py3Dmol.view({"viewergrid": None, "style": (10, 10)}).rotate(-90, "x")#.rotate(-90, "x")


with open(dir_name+"/optimized0.xyz", "r") as f:
    rl = f.read()
mol.addModel(rl,  'xyz', {"style": "stick"})
color="red"
mol_=copy.deepcopy(mol)
mol_.addModel(rl,  'xyz', {"style": "sphere"})
center_local=[param[1]*np.cos(np.radians(90)),0,param[1]*np.sin(np.radians(90))]
d=4
radius_=0.025
color_="gray"

# mol_.addArrow(
#     {"start": {"x": 0, "y": 0, "z": -d},
#      "end": {"x": 0, "y": 0, "z": d}, "radius": radius_,
#      "radiusRatio": 4, "mid": 0.9, "color": color_})
for i in range(200):
    k=(i/100)
    j=((i+1)/100)
    opacity=1-1*(i/200)
    radius_local=radius*center[2]*k/4
    mol_.addCylinder({"start":{"x": center_local[0]*k, "y": center_local[1]*k, "z": center_local[2]*k},
                     "end":{"x": center_local[0]*j, "y": center_local[1]*j, "z": center_local[2]*j},
                     "radius":radius_local,"color":color,'opacity':opacity,"wireframe": False})
    mol_.addCylinder({"start":{"x": center_local[0]*k, "y": center_local[1]*k, "z": -center_local[2]*k},
                     "end":{"x": center_local[0]*j, "y": center_local[1]*j, "z": -center_local[2]*j},
                     "radius":radius_local,"color":color,'opacity':opacity,"wireframe": False})
mol_.show()

###
mol_=copy.deepcopy(mol)
# render_moleculer.addxyzarrow(mol_)
for i in range(100):
    k=(1+i/100)
    j=(1+(i+1)/100)
    opacity=1-1*(i/100)
    mol_.addCylinder({"start":{"x": center[0]*k, "y": center[1]*k, "z": center[2]*k},
                     "end":{"x": center[0]*j, "y": center[1]*j, "z": center[2]*j},
                     "radius":radius,"color":color,'opacity':opacity,"wireframe": False})
    mol_.addCylinder({"start":{"x": center[0]*k, "y": center[1]*k, "z": -center[2]*k},
                     "end":{"x": center[0]*j, "y": center[1]*j, "z": -center[2]*j},
                     "radius":radius,"color":color,'opacity':opacity,"wireframe": False})
mol_.addSphere(
        {"center": {"x": center[0], "y": center[1], "z": center[2]}, 'opacity': 1, "radius": radius,
         "color": color,"wireframe":False})
mol_.addSphere(
        {"center": {"x": center[0], "y": center[1], "z": -center[2]}, 'opacity': 1, "radius": radius,
         "color": color,"wireframe":False})
mol_.show()

###
if True:
    with open(dir_name+"/Dt0.cube", "r") as f:
        rl = f.read()
    render_moleculer.add_label(mol,param,center)
    mol.addSphere(
            {"center": {"x": center[0], "y": center[1], "z": center[2]}, 'opacity': 0.9, "radius": radius,
             "color": color,"wireframe":True})
    
    
    mol.addSphere(
            {"center": {"x": center[0], "y": center[1], "z": -center[2]}, 'opacity': 0.9, "radius": radius,
             "color": color,"wireframe":True})
    mol_=copy.deepcopy(mol)
    
    #mol_.addVolumetricData(rl, 'cube', {'isoval': 0.02, 'color': 'black', 'opacity': 0.5, "wireframe": True})
    if False:
        for isoval,opacity in zip([0.02],[1]):
# Out:
# <div id="3dmolviewer_1706843358283273"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1706843358283273" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_1706843358283273 = null;
# var warn = document.getElementById("3dmolwarning_1706843358283273");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1706843358283273 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1706843358283273"),{backgroundColor:"white"});
# $3Dmol.download("{'viewergrid': None, 'style': (10, 10)}", viewer_1706843358283273, {}, function() {
# viewer_1706843358283273.zoomTo();
# 	viewer_1706843358283273.rotate(-90,"x");
# 	viewer_1706843358283273.addModel("18\n-218362.0798083462\nO                     1.211014000000     0.000000000000     0.000000000000\nC                     0.000000000000     0.000000000000     0.000000000000\nC                    -0.933772000000    -1.210498000000    -0.011803000000\nC                    -2.145136000000    -0.660996000000     0.775569000000\nC                    -1.512989000000    -1.271730000000    -1.458195000000\nC                    -2.471564000000    -0.037596000000    -1.519427000000\nC                    -2.323403000000     0.594880000000    -0.113755000000\nC                    -0.922277000000     1.235317000000    -0.011803000000\nH                    -0.458100000000    -2.130661000000     0.331064000000\nH                    -3.009179000000    -1.334476000000     0.749989000000\nH                    -1.914587000000    -0.423610000000     1.820777000000\nH                    -2.061499000000    -2.210544000000    -1.590602000000\nH                    -0.726828000000    -1.243833000000    -2.219162000000\nH                    -2.202369000000     0.664212000000    -2.316135000000\nH                    -3.505988000000    -0.350518000000    -1.697767000000\nH                    -3.141615000000     1.264242000000     0.164860000000\nH                    -0.792202000000     1.786808000000     0.928953000000\nH                    -0.662808000000     1.916114000000    -0.830063000000\n\n","xyz",{"style": "stick"});
# 	viewer_1706843358283273.addModel("18\n-218362.0798083462\nO                     1.211014000000     0.000000000000     0.000000000000\nC                     0.000000000000     0.000000000000     0.000000000000\nC                    -0.933772000000    -1.210498000000    -0.011803000000\nC                    -2.145136000000    -0.660996000000     0.775569000000\nC                    -1.512989000000    -1.271730000000    -1.458195000000\nC                    -2.471564000000    -0.037596000000    -1.519427000000\nC                    -2.323403000000     0.594880000000    -0.113755000000\nC                    -0.922277000000     1.235317000000    -0.011803000000\nH                    -0.458100000000    -2.130661000000     0.331064000000\nH                    -3.009179000000    -1.334476000000     0.749989000000\nH                    -1.914587000000    -0.423610000000     1.820777000000\nH                    -2.061499000000    -2.210544000000    -1.590602000000\nH                    -0.726828000000    -1.243833000000    -2.219162000000\nH                    -2.202369000000     0.664212000000    -2.316135000000\nH                    -3.505988000000    -0.350518000000    -1.697767000000\nH                    -3.141615000000     1.264242000000     0.164860000000\nH                    -0.792202000000     1.786808000000     0.928953000000\nH                    -0.662808000000     1.916114000000    -0.830063000000\n\n","xyz",{"style": "sphere"});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 6.123233995736766e-19, "y": 0.0, "z": 0.01}, "radius": 0.0, "color": "red", "opacity": 1.0, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 0.0, "y": 0.0, "z": -0.0}, "end": {"x": 6.123233995736766e-19, "y": 0.0, "z": -0.01}, "radius": 0.0, "color": "red", "opacity": 1.0, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 6.123233995736766e-19, "y": 0.0, "z": 0.01}, "end": {"x": 1.2246467991473532e-18, "y": 0.0, "z": 0.02}, "radius": 0.0025, "color": "red", "opacity": 0.995, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 6.123233995736766e-19, "y": 0.0, "z": -0.01}, "end": {"x": 1.2246467991473532e-18, "y": 0.0, "z": -0.02}, "radius": 0.0025, "color": "red", "opacity": 0.995, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 1.2246467991473532e-18, "y": 0.0, "z": 0.02}, "end": {"x": 1.8369701987210296e-18, "y": 0.0, "z": 0.03}, "radius": 0.005, "color": "red", "opacity": 0.99, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 1.2246467991473532e-18, "y": 0.0, "z": -0.02}, "end": {"x": 1.8369701987210296e-18, "y": 0.0, "z": -0.03}, "radius": 0.005, "color": "red", "opacity": 0.99, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 1.8369701987210296e-18, "y": 0.0, "z": 0.03}, "end": {"x": 2.4492935982947064e-18, "y": 0.0, "z": 0.04}, "radius": 0.0075, "color": "red", "opacity": 0.985, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 1.8369701987210296e-18, "y": 0.0, "z": -0.03}, "end": {"x": 2.4492935982947064e-18, "y": 0.0, "z": -0.04}, "radius": 0.0075, "color": "red", "opacity": 0.985, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 2.4492935982947064e-18, "y": 0.0, "z": 0.04}, "end": {"x": 3.061616997868383e-18, "y": 0.0, "z": 0.05}, "radius": 0.01, "color": "red", "opacity": 0.98, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 2.4492935982947064e-18, "y": 0.0, "z": -0.04}, "end": {"x": 3.061616997868383e-18, "y": 0.0, "z": -0.05}, "radius": 0.01, "color": "red", "opacity": 0.98, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 3.061616997868383e-18, "y": 0.0, "z": 0.05}, "end": {"x": 3.673940397442059e-18, "y": 0.0, "z": 0.06}, "radius": 0.0125, "color": "red", "opacity": 0.975, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 3.061616997868383e-18, "y": 0.0, "z": -0.05}, "end": {"x": 3.673940397442059e-18, "y": 0.0, "z": -0.06}, "radius": 0.0125, "color": "red", "opacity": 0.975, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 3.673940397442059e-18, "y": 0.0, "z": 0.06}, "end": {"x": 4.286263797015737e-18, "y": 0.0, "z": 0.07}, "radius": 0.015, "color": "red", "opacity": 0.97, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 3.673940397442059e-18, "y": 0.0, "z": -0.06}, "end": {"x": 4.286263797015737e-18, "y": 0.0, "z": -0.07}, "radius": 0.015, "color": "red", "opacity": 0.97, "wireframe": false});
# 	viewer_1706843358283273.addCylinder({"start": {"x": 4.286263797015737e-18, "y": 0.0, "z": 0.07}, "end": {"x": 4.898587196589413e-18
# <div id="3dmolviewer_17068433582875369"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17068433582875369" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17068433582875369 = null;
# var warn = document.getElementById("3dmolwarning_17068433582875369");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17068433582875369 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17068433582875369"),{backgroundColor:"white"});
# $3Dmol.download("{'viewergrid': None, 'style': (10, 10)}", viewer_17068433582875369, {}, function() {
# viewer_17068433582875369.zoomTo();
# 	viewer_17068433582875369.rotate(-90,"x");
# 	viewer_17068433582875369.addModel("18\n-218362.0798083462\nO                     1.211014000000     0.000000000000     0.000000000000\nC                     0.000000000000     0.000000000000     0.000000000000\nC                    -0.933772000000    -1.210498000000    -0.011803000000\nC                    -2.145136000000    -0.660996000000     0.775569000000\nC                    -1.512989000000    -1.271730000000    -1.458195000000\nC                    -2.471564000000    -0.037596000000    -1.519427000000\nC                    -2.323403000000     0.594880000000    -0.113755000000\nC                    -0.922277000000     1.235317000000    -0.011803000000\nH                    -0.458100000000    -2.130661000000     0.331064000000\nH                    -3.009179000000    -1.334476000000     0.749989000000\nH                    -1.914587000000    -0.423610000000     1.820777000000\nH                    -2.061499000000    -2.210544000000    -1.590602000000\nH                    -0.726828000000    -1.243833000000    -2.219162000000\nH                    -2.202369000000     0.664212000000    -2.316135000000\nH                    -3.505988000000    -0.350518000000    -1.697767000000\nH                    -3.141615000000     1.264242000000     0.164860000000\nH                    -0.792202000000     1.786808000000     0.928953000000\nH                    -0.662808000000     1.916114000000    -0.830063000000\n\n","xyz",{"style": "stick"});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.123233995736766e-17, "y": 0.0, "z": 1.0}, "end": {"x": 6.184466335694134e-17, "y": 0.0, "z": 1.01}, "radius": 1, "color": "red", "opacity": 1.0, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.123233995736766e-17, "y": 0.0, "z": -1.0}, "end": {"x": 6.184466335694134e-17, "y": 0.0, "z": -1.01}, "radius": 1, "color": "red", "opacity": 1.0, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.184466335694134e-17, "y": 0.0, "z": 1.01}, "end": {"x": 6.245698675651501e-17, "y": 0.0, "z": 1.02}, "radius": 1, "color": "red", "opacity": 0.99, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.184466335694134e-17, "y": 0.0, "z": -1.01}, "end": {"x": 6.245698675651501e-17, "y": 0.0, "z": -1.02}, "radius": 1, "color": "red", "opacity": 0.99, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.245698675651501e-17, "y": 0.0, "z": 1.02}, "end": {"x": 6.306931015608869e-17, "y": 0.0, "z": 1.03}, "radius": 1, "color": "red", "opacity": 0.98, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.245698675651501e-17, "y": 0.0, "z": -1.02}, "end": {"x": 6.306931015608869e-17, "y": 0.0, "z": -1.03}, "radius": 1, "color": "red", "opacity": 0.98, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.306931015608869e-17, "y": 0.0, "z": 1.03}, "end": {"x": 6.368163355566237e-17, "y": 0.0, "z": 1.04}, "radius": 1, "color": "red", "opacity": 0.97, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.306931015608869e-17, "y": 0.0, "z": -1.03}, "end": {"x": 6.368163355566237e-17, "y": 0.0, "z": -1.04}, "radius": 1, "color": "red", "opacity": 0.97, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.368163355566237e-17, "y": 0.0, "z": 1.04}, "end": {"x": 6.429395695523605e-17, "y": 0.0, "z": 1.05}, "radius": 1, "color": "red", "opacity": 0.96, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.368163355566237e-17, "y": 0.0, "z": -1.04}, "end": {"x": 6.429395695523605e-17, "y": 0.0, "z": -1.05}, "radius": 1, "color": "red", "opacity": 0.96, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.429395695523605e-17, "y": 0.0, "z": 1.05}, "end": {"x": 6.490628035480972e-17, "y": 0.0, "z": 1.06}, "radius": 1, "color": "red", "opacity": 0.95, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.429395695523605e-17, "y": 0.0, "z": -1.05}, "end": {"x": 6.490628035480972e-17, "y": 0.0, "z": -1.06}, "radius": 1, "color": "red", "opacity": 0.95, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.490628035480972e-17, "y": 0.0, "z": 1.06}, "end": {"x": 6.55186037543834e-17, "y": 0.0, "z": 1.07}, "radius": 1, "color": "red", "opacity": 0.94, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.490628035480972e-17, "y": 0.0, "z": -1.06}, "end": {"x": 6.55186037543834e-17, "y": 0.0, "z": -1.07}, "radius": 1, "color": "red", "opacity": 0.94, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.55186037543834e-17, "y": 0.0, "z": 1.07}, "end": {"x": 6.613092715395707e-17, "y": 0.0, "z": 1.08}, "radius": 1, "color": "red", "opacity": 0.9299999999999999, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.55186037543834e-17, "y": 0.0, "z": -1.07}, "end": {"x": 6.613092715395707e-17, "y": 0.0, "z": -1.08}, "radius": 1, "color": "red", "opacity": 0.9299999999999999, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.613092715395707e-17, "y": 0.0, "z": 1.08}, "end": {"x": 6.674325055353075e-17, "y": 0.0, "z": 1.09}, "radius": 1, "color": "red", "opacity": 0.92, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.613092715395707e-17, "y": 0.0, "z": -1.08}, "end": {"x": 6.674325055353075e-17, "y": 0.0, "z": -1.09}, "radius": 1, "color": "red", "opacity": 0.92, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.674325055353075e-17, "y": 0.0, "z": 1.09}, "end": {"x": 6.735557395310444e-17, "y": 0.0, "z": 1.1}, "radius": 1, "color": "red", "opacity": 0.91, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.674325055353075e-17, "y": 0.0, "z": -1.09}, "end": {"x": 6.735557395310444e-17, "y": 0.0, "z": -1.1}, "radius": 1, "color": "red", "opacity": 0.91, "wireframe": false});
# 	viewer_17068433582875369.addCylinder({"start": {"x": 6.735557395310444e-17, "y": 0.0, "z": 1.1}, "end": {"x": 6.796789735267811e-17, "y": 0.0, "z": 1.11}, "radius": 1, "color": "red", "opacity": 0.9, "wireframe": false});
# 	vie
# <div id="3dmolviewer_1706843358404039"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1706843358404039" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_1706843358404039 = null;
# var warn = document.getElementById("3dmolwarning_1706843358404039");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1706843358404039 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1706843358404039"),{backgroundColor:"white"});
# $3Dmol.download("{'viewergrid': None, 'style': (10, 10)}", viewer_1706843358404039, {}, function() {
# viewer_1706843358404039.zoomTo();
# 	viewer_1706843358404039.rotate(-90,"x");
# 	viewer_1706843358404039.addModel("18\n-218362.0798083462\nO                     1.211014000000     0.000000000000     0.000000000000\nC                     0.000000000000     0.000000000000     0.000000000000\nC                    -0.933772000000    -1.210498000000    -0.011803000000\nC                    -2.145136000000    -0.660996000000     0.775569000000\nC                    -1.512989000000    -1.271730000000    -1.458195000000\nC                    -2.471564000000    -0.037596000000    -1.519427000000\nC                    -2.323403000000     0.594880000000    -0.113755000000\nC                    -0.922277000000     1.235317000000    -0.011803000000\nH                    -0.458100000000    -2.130661000000     0.331064000000\nH                    -3.009179000000    -1.334476000000     0.749989000000\nH                    -1.914587000000    -0.423610000000     1.820777000000\nH                    -2.061499000000    -2.210544000000    -1.590602000000\nH                    -0.726828000000    -1.243833000000    -2.219162000000\nH                    -2.202369000000     0.664212000000    -2.316135000000\nH                    -3.505988000000    -0.350518000000    -1.697767000000\nH                    -3.141615000000     1.264242000000     0.164860000000\nH                    -0.792202000000     1.786808000000     0.928953000000\nH                    -0.662808000000     1.916114000000    -0.830063000000\n\n","xyz",{"style": "stick"});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.8});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.8});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": 1.0}, "end": {"x": 1.0, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": 1.0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": -1.0}, "end": {"x": 1.0, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_1706843358404039.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": -1.0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.5, "y": 0, "z": 0.0}, "end": {"x": 0.4999078560608221, "y": 0, "z": 0.009598721199844834}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.5, "y": 0, "z": -0.0}, "end": {"x": 0.4999078560608221, "y": 0, "z": -0.009598721199844834}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.49992384757819563, "y": 0, "z": 0.008726203218641756}, "end": {"x": 0.4996641968893281, "y": 0, "z": 0.018321854353278138}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.49992384757819563, "y": 0, "z": -0.008726203218641756}, "end": {"x": 0.4996641968893281, "y": 0, "z": -0.018321854353278138}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4996954135095479, "y": 0, "z": 0.017449748351250485}, "end": {"x": 0.49926833516310587, "y": 0, "z": 0.027039406492387646}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4996954135095479, "y": 0, "z": -0.017449748351250485}, "end": {"x": 0.49926833516310587, "y": 0, "z": -0.027039406492387646}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4993147673772869, "y": 0, "z": 0.026167978121471917}, "end": {"x": 0.498720391465472, "y": 0, "z": 0.03574872216634296}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4993147673772869, "y": 0, "z": -0.026167978121471917}, "end": {"x": 0.498720391465472, "y": 0, "z": -0.03574872216634296}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4987820251299121, "y": 0, "z": 0.03487823687206265}, "end": {"x": 0.49802053270538477, "y": 0, "z": 0.04444714843322076}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4987820251299121, "y": 0, "z": -0.03487823687206265}, "end": {"x": 0.49802053270538477, "y": 0, "z": -0.04444714843322076}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4980973490458728, "y": 0, "z": 0.04357787137382908}, "end": {"x": 0.4971689720666023, "y": 0, "z": 0.0531320356681166}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4980973490458728, "y": 0, "z": -0.04357787137382908}, "end": {"x": 0.4971689720666023, "y": 0, "z": -0.0531320356681166}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.49726094768413664, "y": 0, "z": 0.052264231633826735}, "end": {"x": 0.49616596894274434, "y": 0, "z": 0.06180073837024635}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.49726094768413664, "y": 0, "z": -0.052264231633826735}, "end": {"x": 0.49616596894274434, "y": 0, "z": -0.06180073837024635}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.496273075820661, "y": 0, "z": 0.06093467170257374}, "end": {"x": 0.49501182885827877, "y": 0, "z": 0.07045061596879133}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.496273075820661, "y": 0, "z": -0.06093467170257374}, "end": {"x": 0.49501182885827877, "y": 0, "z": -0.07045061596879133}, "radius": 0.05, "color": "black"});
# 	viewer_1706843358404039.addCylinder({"start": {"x": 0.4951340343707852, "y": 0, "z": 0.06958655048003272}, "end": {"x": 0.4937069033754557, "y": 0, "z": 0.07907903362724177}, "radius": 0.05, "color": "black"});
# 	viewe
# <div id="3dmolviewer_17068433584772701"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17068433584772701" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17068433584772701 = null;
# var warn = document.getElementById("3dmolwarning_17068433584772701");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17068433584772701 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17068433584772701"),{backgroundColor:"white"});
# $3Dmol.download("{'viewergrid': None, 'style': (10, 10)}", viewer_17068433584772701, {}, function() {
# viewer_17068433584772701.zoomTo();
# 	viewer_17068433584772701.rotate(-90,"x");
# 	viewer_17068433584772701.addModel("18\n-218362.0798083462\nO                     1.211014000000     0.000000000000     0.000000000000\nC                     0.000000000000     0.000000000000     0.000000000000\nC                    -0.933772000000    -1.210498000000    -0.011803000000\nC                    -2.145136000000    -0.660996000000     0.775569000000\nC                    -1.512989000000    -1.271730000000    -1.458195000000\nC                    -2.471564000000    -0.037596000000    -1.519427000000\nC                    -2.323403000000     0.594880000000    -0.113755000000\nC                    -0.922277000000     1.235317000000    -0.011803000000\nH                    -0.458100000000    -2.130661000000     0.331064000000\nH                    -3.009179000000    -1.334476000000     0.749989000000\nH                    -1.914587000000    -0.423610000000     1.820777000000\nH                    -2.061499000000    -2.210544000000    -1.590602000000\nH                    -0.726828000000    -1.243833000000    -2.219162000000\nH                    -2.202369000000     0.664212000000    -2.316135000000\nH                    -3.505988000000    -0.350518000000    -1.697767000000\nH                    -3.141615000000     1.264242000000     0.164860000000\nH                    -0.792202000000     1.786808000000     0.928953000000\nH                    -0.662808000000     1.916114000000    -0.830063000000\n\n","xyz",{"style": "stick"});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.8});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.8});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": 1.0}, "end": {"x": 1.0, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": 1.0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": 1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": -1.0}, "end": {"x": 1.0, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_17068433584772701.addArrow({"start": {"x": 0.5000000000000001, "y": 0, "z": -1.0}, "end": {"x": 6.123233995736766e-17, "y": 0, "z": -1.0}, "radius": 0.05, "color": "black", "radiusRatio": 3, "mid": 0.5});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.5, "y": 0, "z": 0.0}, "end": {"x": 0.4999078560608221, "y": 0, "z": 0.009598721199844834}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.5, "y": 0, "z": -0.0}, "end": {"x": 0.4999078560608221, "y": 0, "z": -0.009598721199844834}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.49992384757819563, "y": 0, "z": 0.008726203218641756}, "end": {"x": 0.4996641968893281, "y": 0, "z": 0.018321854353278138}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.49992384757819563, "y": 0, "z": -0.008726203218641756}, "end": {"x": 0.4996641968893281, "y": 0, "z": -0.018321854353278138}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4996954135095479, "y": 0, "z": 0.017449748351250485}, "end": {"x": 0.49926833516310587, "y": 0, "z": 0.027039406492387646}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4996954135095479, "y": 0, "z": -0.017449748351250485}, "end": {"x": 0.49926833516310587, "y": 0, "z": -0.027039406492387646}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4993147673772869, "y": 0, "z": 0.026167978121471917}, "end": {"x": 0.498720391465472, "y": 0, "z": 0.03574872216634296}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4993147673772869, "y": 0, "z": -0.026167978121471917}, "end": {"x": 0.498720391465472, "y": 0, "z": -0.03574872216634296}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4987820251299121, "y": 0, "z": 0.03487823687206265}, "end": {"x": 0.49802053270538477, "y": 0, "z": 0.04444714843322076}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4987820251299121, "y": 0, "z": -0.03487823687206265}, "end": {"x": 0.49802053270538477, "y": 0, "z": -0.04444714843322076}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4980973490458728, "y": 0, "z": 0.04357787137382908}, "end": {"x": 0.4971689720666023, "y": 0, "z": 0.0531320356681166}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4980973490458728, "y": 0, "z": -0.04357787137382908}, "end": {"x": 0.4971689720666023, "y": 0, "z": -0.0531320356681166}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.49726094768413664, "y": 0, "z": 0.052264231633826735}, "end": {"x": 0.49616596894274434, "y": 0, "z": 0.06180073837024635}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.49726094768413664, "y": 0, "z": -0.052264231633826735}, "end": {"x": 0.49616596894274434, "y": 0, "z": -0.06180073837024635}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.496273075820661, "y": 0, "z": 0.06093467170257374}, "end": {"x": 0.49501182885827877, "y": 0, "z": 0.07045061596879133}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.496273075820661, "y": 0, "z": -0.06093467170257374}, "end": {"x": 0.49501182885827877, "y": 0, "z": -0.07045061596879133}, "radius": 0.05, "color": "black"});
# 	viewer_17068433584772701.addCylinder({"start": {"x": 0.4951340343707852, "y": 0, "z": 0.06958655048003272}, "end": {"x": 0.4937069033754557, "y": 0, "z": 0.07907903362724177}, "radius":

# %%
mol_.png()
# Out:
# <img id="img_170684292799556">
#             <script>
#             var png = viewer_170684292799556.pngURI()
#             document.getElementById('img_170684292799556').src = png;
#             </script>

# %%
# with open(dir_name+"/Dt02_0.cube", "r") as f:
#     Dt = f.read().splitlines()
# with open(dir_name+"/DUAL02_0.cube","r") as f:
#     LUMO = f.read().splitlines()
# l = np.array([_.split() for _ in Dt[2:6]])
# n_atom = int(l[0, 0])
# x0 = l[0, 1:].astype(float)
# size = l[1:, 0].astype(int)
# axis = l[1:, 1:].astype(float)
# Dt = np.concatenate([_.split() for _ in Dt[3 + 3 + n_atom:]]).astype(float).reshape(-1, 1)
# LUMO = np.concatenate([_.split() for _ in LUMO[3 + 3 + n_atom:]]).astype(float).reshape(-1, 1)
# l = np.array(list(product(range(size[0]), range(size[1]), range(size[2])))) @ axis + x0
# l = l * 0.52917720859
# arr = np.concatenate([l, Dt, LUMO], axis=1)
# df = pd.DataFrame(arr, columns=["x", "y", "z", "Dt", "LUMO"])

# %%
# cent_up = np.array(center)
# cent_down = np.array(center) * np.array([1, -1, -1])
# d_up = np.linalg.norm(l - cent_up, axis=1)
# d_down = np.linalg.norm(l - cent_down, axis=1)
# interior_space_up = d_up < radius
# interior_space_down = d_down < radius
# data_up = df[interior_space_up]
# data_down = df[interior_space_down]
# param={"feature":["Dt","LUMO"]}
# if "Dt" in param["feature"]:
#     Dt_up = data_up["Dt"].to_numpy()
#     Dt_down = data_down["Dt"].to_numpy()
#     isoval = 0.02
#     Dt = np.sum(np.where(Dt_up < isoval, Dt_up, isoval)), np.sum(np.where(Dt_down < isoval, Dt_down, isoval))
#     Dt=np.array(Dt)
# if "LUMO" in param["feature"]:
#     LUMO_up = data_up["LUMO"].to_numpy()
#     LUMO_down = data_down["LUMO"].to_numpy()
#     LUMO = np.abs(np.sum(LUMO_up[LUMO_up > 0] ** 2) - np.sum(LUMO_up[LUMO_up < 0] ** 2)),\
#     np.abs(np.sum(LUMO_down[LUMO_down > 0] ** 2) - np.sum(LUMO_down[LUMO_down < 0] ** 2))
#     LUMO=np.array(LUMO)
# if "DUAL" in param["feature"]:
#     DUAL_up = data_up["LUMO"].to_numpy()
#     DUAL_down = data_down["LUMO"].to_numpy()
#     DUAL = (np.sum(LUMO_up) - np.sum(LUMO_up[LUMO_up < 0] ** 2)),\
#     np.abs(np.sum(LUMO_down[LUMO_down > 0] ** 2) - np.sum(LUMO_down[LUMO_down < 0] ** 2))
# print(Dt*(0.2* 0.52917720859)**3,Dt[0]-Dt[1])
# print(LUMO*(0.2* 0.52917720859)**3,LUMO[0]-LUMO[1])
# print((Dt[0]-Dt[1])*coef[0],(LUMO[0]-LUMO[1])*coef[1],(Dt[0]-Dt[1])*coef[0]+(LUMO[0]-LUMO[1])*coef[1])
# *(0.2*0.52917720859)**3
